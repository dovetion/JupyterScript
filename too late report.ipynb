# %% [markdown]
# ### 测试1
#
# * 每30s发送包一次，对时间进行测试，共50个合法包
#
# * 其中 “射频接收”到“上传服务器”之间的平均耗时：11.14ms，标准差0.34ms
# * “上传服务器”到收到“服务器下行”的平均耗时：519.56ms，标准差314.18ms
# * 网关收到“服务器下行”到下行包入队的平均耗时：0.34ms，标准差0.47ms
# * 总体平均延时为 531.04ms
#
# data:image/png;base64,...![image.png](attachment:image.png)

# %% [markdown]
# 延迟的峰值间隔周期为 10，15，13，15
# 延迟的波谷间隔周期为 17，13

# %% [markdown]
# 当天的第二次测试结果如下：
# 为了简化数据处理过程就没有再分段计算延时，而是直接使用了从“收包”到“入队”的总延时
#
# data:image/png;base64,...![image.png](attachment:image.png)

# %% [markdown]
# 平均的总体延时为 544.07ms

# %% [markdown]
# 延时呈现出规律地的周期性变化，波峰的出现常超过1s，故此时会造成TOO LATE下行请求拒绝

# %% [markdown]
# ### 第三次长时间测试
#
# 200+个包，20s发一次
# 平均延时535.78ms
# 标准差298.09ms
# data:image/png;base64,...![image.png](attachment:image.png)

# %% [markdown]
# 可以看出平均时延基本都是530~540ms之间，标准差基本都在300ms左右，但是变化非常有规律，这个规律基本也符合10%的too late下行拒绝率
# 问题出现在 “上传服务器”到“收到下行json”这段时间，但是造成问题的具体原因目前还不清楚
#
# 周期大概在11～13分钟左右
