# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
py_1_error = np.loadtxt("/Users/gexin/Desktop/result/py_1_err.txt", delimiter=" ")
py_2_error = np.loadtxt("/Users/gexin/Desktop/result/py_2_err.txt", delimiter=" ")

matlab_1_error = np.loadtxt("/Users/gexin/Desktop/result/matlab_1_err.txt", delimiter=" ")
matlab_2_error = np.loadtxt("/Users/gexin/Desktop/result/matlab_2_err.txt", delimiter=" ")

py_1_time = np.loadtxt("/Users/gexin/Desktop/result/py_1_time.txt",delimiter=" ")
py_2_time = np.loadtxt("/Users/gexin/Desktop/result/py_2_time.txt",delimiter=" ")

matlab_1_time = np.loadtxt("/Users/gexin/Desktop/result/matlab_1_time.txt",delimiter=" ")
matlab_2_time = np.loadtxt("/Users/gexin/Desktop/result/matlab_2_time.txt",delimiter=" ")

py_1_maxerr = np.loadtxt("/Users/gexin/Desktop/result/py_1_maxerr.txt", delimiter=" ")
py_2_maxerr = np.loadtxt("/Users/gexin/Desktop/result/py_2_maxerr.txt", delimiter=" ")

matlab_1_maxerr = np.loadtxt("/Users/gexin/Desktop/result/matlab_1_maxerr.txt", delimiter=" ")
matlab_2_maxerr = np.loadtxt("/Users/gexin/Desktop/result/matlab_2_maxerr.txt", delimiter=" ")

# %% [markdown]
# ### error on test 1

# %%
plt.figure(figsize=(8, 6), dpi=100) 
plt.xlabel('size of matrix')  
plt.ylabel('error on test 1')  
x = [i for i in range(2,1001)] 
plt.plot(x,py_1_error,"*",label="python error")  
plt.plot(x,matlab_1_error,"+",label="matlab error")  
plt.grid(True)    
plt.show()

# %% [markdown]
# ### max error on test 1

# %%
plt.figure(figsize=(8, 6), dpi=100) 
plt.xlabel('size of matrix')  
plt.ylabel('max error on test 1')  
x = [i for i in range(0,999)] 
plt.plot(x,py_1_maxerr,"*",label="python error")  
plt.plot(x,matlab_1_maxerr,"+",label="matlab error")  
plt.grid(True)  
plt.show()

# %% [markdown]
# ### time on test 1

# %%
plt.figure(figsize=(8, 6), dpi=100) 
plt.xlabel('size of matrix')  
plt.ylabel('time on test 1')  
x = [i for i in range(0,999)] 
plt.plot(x,py_1_time,"*",label="python error")  
plt.plot(x,matlab_1_time,"+",label="matlab error")  
plt.grid(True)  
plt.show()

# %% [markdown]
# ### error on test 2

# %%
plt.figure(figsize=(8, 6), dpi=100) 
plt.xlabel('size of matrix')  
plt.ylabel('error on test 2')  
x = [i for i in range(0,999)] 
plt.plot(x,py_2_error,"*",label="python error")  
plt.plot(x,matlab_2_error,"+",label="matlab error")  
plt.grid(True)  
plt.show()

# %% [markdown]
# ### max error on test 2

# %%
plt.figure(figsize=(8, 6), dpi=100) 
plt.xlabel('size of matrix')  
plt.ylabel('max error on test 2')  
x = [i for i in range(0,999)] 
plt.plot(x,py_2_maxerr,"*",label="python error")  
plt.plot(x,matlab_2_maxerr,"+",label="matlab error")  
plt.grid(True)  
plt.show()

# %% [markdown]
# ### time on test 2

# %%
plt.figure(figsize=(8, 6), dpi=100) 
plt.xlabel('size of matrix')  
plt.ylabel('time on test 2')  
x = [i for i in range(0,999)] 
plt.plot(x,py_2_time,"*",label="python error")  
plt.plot(x,matlab_2_time,"+",label="matlab error")  
plt.grid(True)  
plt.show()
