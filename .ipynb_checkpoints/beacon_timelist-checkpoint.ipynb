# %%
### gexin
### calculate next 100 beacons' time 
### when it hits the time, play audio

import time
from pygame import mixer
mixer.init() #you must initialize the mixer
alert=mixer.Sound('bell.wav')
alert.play()


ticks = time.time()
tick = int(ticks)
if(tick%128) != 0:
    tick += 128 - (tick%128);
localtime = time.localtime(tick)

beacon_list = []
time_list = []
while len(beacon_list) != 100:
    s = time.strftime("%Y-%m-%d %H:%M:%S", localtime)
    beacon_list.append(s)
    time_list.append(localtime)
    tick += 128;
    localtime = time.localtime(tick)

    
for s in beacon_list:
    print(s)

while 1:
    ticks = time.time()
    tick = int(ticks)
    local = time.localtime(tick)
    if local in time_list:
        alert.play()
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-7009cd5c5208> in <module>()
#       6 from pygame import mixer
#       7 mixer.init() #you must initialize the mixer
# ----> 8 alert=mixer.Sound('bell.wav')
#       9 alert.play()
#      10
#
# error: Unable to open file 'bell.wav'
